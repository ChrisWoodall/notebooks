# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('~/Dev/tvsquared-backend/tvsquared/tmp/cw/data/all_clients_jobs_less_than_6_archive_2510_1008.csv', header=0)
df_trimmed =  df.drop(['Unnamed: 0', 'total_cost', 'total_time_in_queue', 
                         'total_time_under_calculation', 'total_time_waiting',
                         'total_time_waiting', 'total_time_under_calculation',
                         'total_cost', 'spot_finish','totalrowcount', 'spot_total', 
                         'spot_start', 'spot_granularity_1', 
                         'workticket_scheduled', 'workticket_started', 'workticket_finished'], axis=1)
print(df_trimmed.head())

cols = df_trimmed.columns.tolist()

new_cols = []
new_cols.insert(0, 'cluster_info')
new_cols.insert(0, 'jobcount')
new_cols.insert(0, 'workticketid')
new_cols.insert(0, 'lag')
new_cols.insert(0, 'origin')
new_cols.insert(0, 'last_job_time')
new_cols.insert(0, 'last_job')
new_cols.insert(0, 'workticket_duration')
new_cols.insert(0, 'jobpriority')
new_cols.insert(0, 'lag_actions')
new_cols.insert(0, 'max_lag')
new_cols.insert(0, 'micro')
new_cols.insert(0, 'diffuse')
new_cols.insert(0, 'spot_duration')
new_cols.insert(0, 'modelrowcount')
new_cols.insert(0, 'rawsize')
new_cols.insert(0, 'slug')
new_cols.insert(0, 'clientid')
new_cols.insert(0, 'brandid')

df_trimmed = df_trimmed[new_cols]
mask = df_trimmed['cluster_info'].str.contains('clone', na=False)
rem_clones = df_trimmed[mask == False]
mask = rem_clones['slug'].str.contains('NaN', na=False)
rem_NaN = rem_clones[mask == False]
rename = rem_NaN.rename(columns={'modelrowcount': 'total_number_of_spots_upld'})
rename.dropna(subset=['slug'], inplace=True)
print (rename)
# Out:
#    brandid  clientid     cluster_info diffuse  jobcount  jobpriority  \
# 0        1       952        {u'4': 1}   False         3       1008.0
# 1        1       367        {u'1': 1}    True         3       1008.0
# 2        1       367        {u'1': 1}    True         3       1008.0
# 3        1      1221        {u'1': 1}   False         5       1008.0
# 4        1      1406  {u'clones1': 1}    True         3       1008.0
#
#                                                 jobs    lag  lag_actions  \
# 0  [u'IMPORTER.ISPOT', u'LOAD.SPOTS', u'INF.SENDE...  False          0.0
# 1  [u'LOAD.SPOTS', u'INF.SENDEMAIL', u'INF.SENDEM...   True          2.0
# 2  [u'LOAD.SPOTS', u'INF.SENDEMAIL', u'INF.SENDEM...   True          2.0
# 3  [u'INF.SENDEMAIL', u'INF.SENDEMAIL', u'LOAD.SP...   True          4.0
# 4  [u'LOAD.SPOTS', u'INF.SENDEMAIL', u'INF.SENDEM...   True          7.0
#
#         last_job  last_job_time  max_lag micro  modelrowcount origin  \
# 0  INF.SENDEMAIL          0.773      0.0  True            NaN  US(2)
# 1  INF.SENDEMAIL          0.797     14.0  True            NaN  US(1)
# 2  INF.SENDEMAIL          1.402     14.0  True            NaN  US(1)
# 3  INF.SENDEMAIL          1.101     14.0  True            NaN  US(1)
# 4  INF.SENDEMAIL          1.998     14.0  True            NaN  US(1)
#
#         rawsize             slug  spot_duration  workticket_duration  \
# 0  6.122316e+10  ihg-holiday-inn            NaN               38.182
# 1  1.130000e+11     madison-reed            NaN               11.619
# 2  1.130000e+11     madison-reed            NaN               16.046
# 3  9.382938e+08            earny            NaN          1617229.190
# 4  1.385913e+09    earny-testing            NaN               26.379
#
#                workticketid
# 0  59a8e955b43fdd3d086b6d6f
# 1  59a9946db43fdd01dc8719fc
# 2  59a99470b43fdd01dc8719ff
# 3  59a99475b43fdd01dc871a01
# 4  59a99478b43fdd01dc871a03
#      brandid  clientid                 slug       rawsize  \
# 0          1       952      ihg-holiday-inn  6.122316e+10
# 1          1       367         madison-reed  1.130000e+11
# 2          1       367         madison-reed  1.130000e+11
# 3          1      1221                earny  9.382938e+08
# 5          1      1337               hollar  2.360000e+11
# 6          1      1338          trippingcom  5.619301e+10
# 7          1      1560          gwynnie-bee  3.255237e+09
# 8          1       952      ihg-holiday-inn  6.122316e+10
# 9          1       952      ihg-holiday-inn  6.122316e+10
# 10         1       367         madison-reed  1.130000e+11
# 11         1       367         madison-reed  1.130000e+11
# 12         1      1221                earny  9.382938e+08
# 14         1      1337               hollar  2.360000e+11
# 15         1      1337               hollar  2.360000e+11
# 16         1      1338          trippingcom  5.619301e+10
# 17         1      1383                 zola  2.872746e+10
# 18         1      1550                 away  1.526642e+10
# 19         1      1731           kiwi-crate  3.699612e+09
# 20         1      1337               hollar  2.360000e+11
# 21         1      1338          trippingcom  5.619301e+10
# 22         1       367         madison-reed  1.130000e+11
# 23         1       367         madison-reed  1.130000e+11
# 24         1      1221                earny  9.382938e+08
# 26         1      1337               hollar  2.360000e+11
# 27         1      1383                 zola  2.872746e+10
# 28         1      1550                 away  1.526642e+10
# 29         1      1731           kiwi-crate  3.699612e+09
# 30         1       952      ihg-holiday-inn  6.122316e+10
# 31         1       939          diabetes-uk  1.705057e+09
# 32         1       939          diabetes-uk  1.705057e+09
# ..       ...       ...                  ...           ...
# 391      121        29              madecom  6.854651e+10
# 392        1      1327      flipp-appsflyer  9.462848e+09
# 393      121        29              madecom  6.854651e+10
# 394      121        29              madecom  6.854651e+10
# 395      121        29              madecom  6.854651e+10
# 396        1      1753        selectspecs-1  7.518275e+08
# 397        1      1753        selectspecs-1  7.518275e+08
# 398        1      1753        selectspecs-1  7.518275e+08
# 399        1      1753        selectspecs-1  7.518275e+08
# 400        1       909       hello-fresh-au  7.027719e+09
# 401        1      1180           expedia-sg  2.768263e+10
# 402        1      1180           expedia-sg  2.768263e+10
# 403        1      1995  tails-manual-upload  3.704489e+08
# 404        1       352        bookingcom-uk  5.190000e+11
# 405        1      1454        glassesusacom  2.697624e+10
# 406        1       611       bookingcom-aus  9.479038e+10
# 407        1       611       bookingcom-aus  9.479038e+10
# 408        1       611       bookingcom-aus  9.479038e+10
# 409        1      1327      flipp-appsflyer  9.462848e+09
# 410        1      1594          godaddy-usa  1.570000e+11
# 411        1      1676         gala-bingo-1  4.425986e+07
# 412        1      1676         gala-bingo-1  4.425986e+07
# 413        1      1594          godaddy-usa  1.570000e+11
# 414        1       908       hello-fresh-uk  1.160434e+10
# 417        1      1871        bookingcom-mx  2.100741e+08
# 420        1      1328  brandman-university  2.788047e+09
# 421        1      1328  brandman-university  2.788047e+09
# 422        1      1328  brandman-university  2.788047e+09
# 423        1      1328  brandman-university  2.788047e+09
# 424        1      1368                shipt  4.554316e+09
#
#      total_number_of_spots_upld  spot_duration diffuse  micro  max_lag  \
# 0                           NaN            NaN   False   True      0.0
# 1                           NaN            NaN    True   True     14.0
# 2                           NaN            NaN    True   True     14.0
# 3                           NaN            NaN   False   True     14.0
# 5                           NaN            NaN    True   True     14.0
# 6                           NaN            NaN    True   True     14.0
# 7                           NaN            NaN   False   True      0.0
# 8                           NaN            NaN   False   True      0.0
# 9                           NaN            NaN   False   True      0.0
# 10                          NaN            NaN    True   True     14.0
# 11                          NaN            NaN    True   True     14.0
# 12                          NaN            NaN   False   True     14.0
# 14                          NaN            NaN    True   True     14.0
# 15                          NaN            NaN    True   True     14.0
# 16                          NaN            NaN    True   True     14.0
# 17                          NaN            NaN    True   True     28.0
# 18                          NaN            NaN    True   True     14.0
# 19                          NaN            NaN    True   True     14.0
# 20                          NaN            NaN    True   True     14.0
# 21                          NaN            NaN    True   True     14.0
# 22                          NaN            NaN    True   True     14.0
# 23                          NaN            NaN    True   True     14.0
# 24                          NaN            NaN   False   True     14.0
# 26                          NaN            NaN    True   True     14.0
# 27                          NaN            NaN    True   True     28.0
# 28                          NaN            NaN    True   True     14.0
# 29                          NaN            NaN    True   True     14.0
# 30                          NaN            NaN   False   True      0.0
# 31                          NaN            NaN   False   True     10.0
# 32                          NaN            NaN   False   True     10.0
# ..                          ...            ...     ...    ...      ...
# 391                         NaN      2678400.0   False  False     28.0
# 392                         NaN      2505600.0   False   True      0.0
# 393                         NaN      2678400.0   False  False     28.0
# 394                         NaN      2678400.0   False  False     28.0
# 395                         NaN      2678400.0   False  False     28.0
# 396                         NaN     18316800.0    True   True     30.0
# 397                         NaN     18316800.0    True   True     30.0
# 398                         NaN     18316800.0    True   True     30.0
# 399                         NaN     18316800.0    True   True     30.0
# 400                         NaN     19872000.0   False   True     14.0
# 401                         NaN      1814400.0   False   True     14.0
# 402                         NaN      1814400.0   False   True     14.0
# 403                         NaN      2419200.0   False   True      0.0
# 404                         NaN      2764800.0   False  False     14.0
# 405                         NaN       691200.0    True   True     90.0
# 406                         NaN       604800.0   False   True     14.0
# 407                         NaN       604800.0   False   True     14.0
# 408                         NaN       604800.0   False   True     14.0
# 409                         NaN       691200.0   False   True      0.0
# 410                         NaN      2419200.0    True   True     14.0
# 411                         NaN      2678400.0   False   True      0.0
# 412                         NaN      2678400.0   False   True      0.0
# 413                         NaN      2419200.0    True   True     14.0
# 414                         NaN      1641600.0   False  False     14.0
# 417                         NaN      1728000.0   False   True      0.0
# 420                         NaN       604800.0    True   True     14.0
# 421                         NaN       604800.0    True   True     14.0
# 422                         NaN       604800.0    True   True     14.0
# 423                         NaN       604800.0    True   True     14.0
# 424                         NaN       604800.0    True   True     28.0
#
#      lag_actions  jobpriority  workticket_duration       last_job  \
# 0            0.0      1008.00               38.182  INF.SENDEMAIL
# 1            2.0      1008.00               11.619  INF.SENDEMAIL
# 2            2.0      1008.00               16.046  INF.SENDEMAIL
# 3            4.0      1008.00          1617229.190  INF.SENDEMAIL
# 5            3.0      1008.00            19814.448  INF.SENDEMAIL
# 6            2.0      1008.00               11.609  INF.SENDEMAIL
# 7            0.0      1008.00               40.521  INF.SENDEMAIL
# 8            0.0      1008.00               33.855  INF.SENDEMAIL
# 9            0.0      1008.00               48.394  INF.SENDEMAIL
# 10           2.0      1008.00               21.276  INF.SENDEMAIL
# 11           2.0      1008.00               18.955  INF.SENDEMAIL
# 12           4.0      1008.00          1437263.068  INF.SENDEMAIL
# 14           3.0      1008.00               30.026  INF.SENDEMAIL
# 15           3.0      1008.00               30.293  INF.SENDEMAIL
# 16           2.0      1008.00               12.430  INF.SENDEMAIL
# 17           5.0      1008.00               11.191  INF.SENDEMAIL
# 18           3.0      1008.00          1437872.428  INF.SENDEMAIL
# 19           2.0      1008.00                6.929  INF.SENDEMAIL
# 20           3.0      1008.00               13.557  INF.SENDEMAIL
# 21           2.0      1008.00               20.292  INF.SENDEMAIL
# 22           2.0      1008.00               26.048  INF.SENDEMAIL
# 23           2.0      1008.00               24.192  INF.SENDEMAIL
# 24           4.0      1008.00          1436105.480  INF.SENDEMAIL
# 26           3.0      1008.00               15.321  INF.SENDEMAIL
# 27           5.0      1008.00               18.996  INF.SENDEMAIL
# 28           3.0      1008.00          1436692.448  INF.SENDEMAIL
# 29           2.0      1008.00               16.009  INF.SENDEMAIL
# 30           0.0      1008.00               95.027  INF.SENDEMAIL
# 31           8.0      1008.00               34.467  INF.SENDEMAIL
# 32           8.0      1008.00                7.755  INF.SENDEMAIL
# ..           ...          ...                  ...            ...
# 391          1.0      1008.01               31.094  INF.SENDEMAIL
# 392          0.0      1008.01               61.202  INF.SENDEMAIL
# 393          1.0      1008.01               31.073  INF.SENDEMAIL
# 394          1.0      1008.01               29.665  INF.SENDEMAIL
# 395          1.0      1008.01               31.053  INF.SENDEMAIL
# 396          1.0      1008.01               31.538  INF.SENDEMAIL
# 397          1.0      1008.01               31.492  INF.SENDEMAIL
# 398          1.0      1008.01               31.224  INF.SENDEMAIL
# 399          1.0      1008.01               31.641  INF.SENDEMAIL
# 400          5.0      1008.01               31.196  INF.SENDEMAIL
# 401          2.0      1008.01               31.397  INF.SENDEMAIL
# 402          2.0      1008.01               31.237  INF.SENDEMAIL
# 403          0.0      1008.01               26.127  INF.SENDEMAIL
# 404          1.0      1008.01               31.151  INF.SENDEMAIL
# 405          4.0      1008.01               25.912  INF.SENDEMAIL
# 406          1.0      1008.01               31.115  INF.SENDEMAIL
# 407          1.0      1008.01               10.166  INF.SENDEMAIL
# 408          1.0      1008.01               20.305  INF.SENDEMAIL
# 409          0.0      1008.01               19.049  INF.SENDEMAIL
# 410          4.0      5008.01              418.952  INF.SENDEMAIL
# 411          0.0      1008.01               30.110  INF.SENDEMAIL
# 412          0.0      1008.01               31.189  INF.SENDEMAIL
# 413          4.0      5009.01             4153.869  INF.SENDEMAIL
# 414          5.0      1008.01               30.966  INF.SENDEMAIL
# 417          0.0      1008.01               31.097  INF.SENDEMAIL
# 420          1.0      1008.01               31.155  INF.SENDEMAIL
# 421          1.0      1008.01               31.273  INF.SENDEMAIL
# 422          1.0      1008.01               31.346  INF.SENDEMAIL
# 423          1.0      1008.01               31.172  INF.SENDEMAIL
# 424          1.0      1008.01               31.508  INF.SENDEMAIL
#
#      last_job_time                                    origin    lag  \
# 0            0.773                                     US(2)  False
# 1            0.797                                     US(1)   True
# 2            1.402                                     US(1)   True
# 3            1.101                                     US(1)   True
# 5            1.024                                     US(1)   True
# 6            0.753                                     US(1)   True
# 7            1.473                                     US(1)  False
# 8            0.759                                     US(2)  False
# 9            0.774                                     US(2)  False
# 10           0.757                                     US(1)   True
# 11           0.748                                     US(1)   True
# 12           1.016                                     US(1)   True
# 14           0.950                                     US(1)   True
# 15           0.852                                     US(1)   True
# 16           0.744                                     US(1)   True
# 17           0.767                                     US(1)   True
# 18           0.924                                     US(1)   True
# 19           0.748                                     US(1)   True
# 20           0.913                                     US(1)   True
# 21           0.744                                     US(1)   True
# 22           0.749                                     US(1)   True
# 23           0.777                                     US(1)   True
# 24           1.208                                     US(1)   True
# 26           0.871                                     US(1)   True
# 27           0.746                                     US(1)   True
# 28           0.937                                     US(1)   True
# 29           0.740                                     US(1)   True
# 30           0.783                                     US(2)  False
# 31           0.827                                     GB(1)   True
# 32           0.751                                     GB(1)   True
# ..             ...                                       ...    ...
# 391          0.943  BE(1), FR(1), NL(1), DE(1), IT(1), GB(1)   True
# 392          0.965                                     US(1)  False
# 393          0.947  BE(1), FR(1), NL(1), DE(1), IT(1), GB(1)   True
# 394          1.781  BE(1), FR(1), NL(1), DE(1), IT(1), GB(1)   True
# 395          0.912  BE(1), FR(1), NL(1), DE(1), IT(1), GB(1)   True
# 396          1.340                                     GB(1)   True
# 397          1.351                                     GB(1)   True
# 398          1.084                                     GB(1)   True
# 399          1.464                                     GB(1)   True
# 400          1.009                                     AU(1)   True
# 401          0.966                                     SG(1)   True
# 402          1.013                                     SG(1)   True
# 403          1.609                                     GB(1)  False
# 404          0.968                                     GB(1)   True
# 405          0.954                                     US(1)   True
# 406          0.932                                     AU(1)   True
# 407          0.913                                     AU(1)   True
# 408          0.950                                     AU(1)   True
# 409          0.927                                     US(1)  False
# 410          1.005                                     US(1)   True
# 411          1.291                                     GB(1)  False
# 412          0.974                                     GB(1)  False
# 413          1.138                                     US(1)   True
# 414          0.920                                     GB(1)   True
# 417          0.954                                     MX(1)  False
# 420          0.938                                     US(1)   True
# 421          0.974                                     US(1)   True
# 422          1.021                                     US(1)   True
# 423          0.923                                     US(1)   True
# 424          1.224                                     US(1)   True
#
#                  workticketid  jobcount cluster_info
# 0    59a8e955b43fdd3d086b6d6f         3    {u'4': 1}
# 1    59a9946db43fdd01dc8719fc         3    {u'1': 1}
# 2    59a99470b43fdd01dc8719ff         3    {u'1': 1}
# 3    59a99475b43fdd01dc871a01         5    {u'1': 1}
# 5    59a9947cb43fdd01dc871a05         3          NaN
# 6    59a99484b43fdd01dc871a09         3    {u'1': 1}
# 7    59a9b08db43fdd2b8d6cbf18         3    {u'4': 1}
# 8    59aa3ad6b43fdd618023ec16         3    {u'4': 1}
# 9    59ab8c56b43fdd5475adc1b0         3    {u'4': 1}
# 10   59ac538db43fdd667ea9e221         3    {u'1': 1}
# 11   59ac538fb43fdd667ea9e224         3    {u'1': 1}
# 12   59ac5391b43fdd667ea9e226         5    {u'1': 1}
# 14   59ac5393b43fdd667ea9e22a         3          NaN
# 15   59ac5394b43fdd667ea9e22c         3          NaN
# 16   59ac5396b43fdd667ea9e22e         3    {u'1': 1}
# 17   59ac5397b43fdd667ea9e230         3    {u'1': 1}
# 18   59ac5398b43fdd667ea9e232         5    {u'1': 1}
# 19   59ac539bb43fdd667ea9e236         3    {u'3': 1}
# 20   59ac55e5b43fdd6a61c6a81a         3          NaN
# 21   59ac55e8b43fdd6a61c6a81d         3    {u'1': 1}
# 22   59ac583db43fdd6dbddecb0d         3    {u'1': 1}
# 23   59ac583fb43fdd6dbddecb10         3    {u'1': 1}
# 24   59ac5840b43fdd6dbddecb12         5    {u'1': 1}
# 26   59ac5842b43fdd6dbddecb16         3          NaN
# 27   59ac5844b43fdd6dbddecb18         3    {u'1': 1}
# 28   59ac5846b43fdd6dbddecb1a         5    {u'1': 1}
# 29   59ac5847b43fdd6dbddecb1c         3    {u'3': 1}
# 30   59acddd6b43fdd4d40d86349         3    {u'4': 1}
# 31   59ad26a575ef3204283a8832         2    {u'1': 1}
# 32   59ad31a680a77c5cc30271f3         2    {u'1': 1}
# ..                        ...       ...          ...
# 391  59d5d1afb712c92a565d16d3         4    {u'3': 1}
# 392  59d633658a8845042cdc66f0         4    {u'1': 1}
# 393  59d64babb712c96a0b5d166d         4    {u'3': 1}
# 394  59d7190c1073a6618ef4b181         4    {u'3': 1}
# 395  59d734dcb712c96a0b5d16c1         4    {u'3': 1}
# 396  59d8694395185d0208eb6cf1         4    {u'3': 1}
# 397  59d86ab4b712c97d7a5d161c         4    {u'3': 1}
# 398  59d86b8c95185d0208eb6cf3         4    {u'3': 1}
# 399  59d86c5d265b36753506b5b4         4    {u'3': 1}
# 400  59dbe23eb712c979275d1609         5    {u'4': 1}
# 401  59dde947265b36151a06b5ca         4    {u'4': 1}
# 402  59dde98b1073a67de7f4b101         4    {u'4': 1}
# 403  59de34e295185d4763eb6b71         4    {u'3': 1}
# 404  59df5bd41073a63516f4b0e2         4    {u'2': 1}
# 405  59dfa22a1073a63516f4b12a         5    {u'1': 1}
# 406  59e079b6265b363b2306b5fd         4    {u'1': 1}
# 407  59e09c2a830bd84949ede304         4    {u'1': 1}
# 408  59e09e5f95185d6d18eb6b77         4    {u'1': 1}
# 409  59e0d0968a88455947dc6749         5    {u'1': 1}
# 410  59e24c641073a66da3f4b0e5         4    {u'2': 1}
# 411  59e5c2ae15d9997648543098         4    {u'1': 1}
# 412  59e5c3101073a64f3df4b0f3         4    {u'1': 1}
# 413  59e6900d95185d20aaeb6bc9         4    {u'2': 1}
# 414  59e889e16639a10436bf2a8d         4    {u'4': 1}
# 417  59e9396d6639a10436bf2b0e         4    {u'3': 1}
# 420  59ee1e866639a11e74bf2b01         4    {u'3': 1}
# 421  59ee27877d571c0433e0bb9b         4    {u'3': 1}
# 422  59ee290e6639a11e74bf2b04         4    {u'3': 1}
# 423  59ee54ea3b34c927ce8c6179         4    {u'3': 1}
# 424  59ef00788de72178ff6a9537         4    {u'4': 1}
#
# [382 rows x 19 columns]

# %%
# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1= plt.gca()

# create the data type to be entered in the graph
ax1.scatter(rename['rawsize'], rename['workticket_duration'], marker="o", color='b', label='workticket durration' )

# chart axes, title and legend
plt.title("workticket duration vs database size")
plt.ylabel("workticket duration")
plt.xlabel("database rawsize")
ax1.set_xscale('log')
ax1.axis([10000000, 2000000000000, -10000,1000000])

# figure boundaries

plt.show()

# %%
rename.sort_values('rawsize')

# getting all values less than 250

wkt_tic_small = rename[rename.workticket_duration < 250]
wkt_tic_small.sort_values('workticket_duration')
wkt_tic_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329 entries, 0 to 424
# Data columns (total 19 columns):
# brandid                       329 non-null int64
# clientid                      329 non-null int64
# slug                          329 non-null object
# rawsize                       329 non-null float64
# total_number_of_spots_upld    22 non-null float64
# spot_duration                 77 non-null float64
# diffuse                       329 non-null object
# micro                         329 non-null object
# max_lag                       329 non-null float64
# lag_actions                   329 non-null float64
# jobpriority                   329 non-null float64
# workticket_duration           329 non-null float64
# last_job                      329 non-null object
# last_job_time                 329 non-null float64
# origin                        329 non-null object
# lag                           329 non-null object
# workticketid                  329 non-null object
# jobcount                      329 non-null int64
# cluster_info                  323 non-null object
# dtypes: float64(8), int64(3), object(8)
# memory usage: 51.4+ KB

# %%
# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1= plt.gca()

# create the data type to be entered in the graph
ax1.scatter(wkt_tic_small['rawsize'], wkt_tic_small['workticket_duration'], marker="o", color='b', label='workticket durration' )

# chart axes, title and legend
plt.title("workticket duration vs database size")
plt.ylabel("workticket duration")
plt.xlabel("database rawsize")
ax1.set_xscale('log')
ax1.axis([10000000, 2000000000000, -10,250])

# figure boundaries

plt.show()

# %%
wkt_tic

# %%
# now get all values about 250

wkt_tic_large = rename[rename.workticket_duration > 500 ]
wkt_tic_large.sort_values('workticket_duration')
wkt_tic_large.info()
wkt_tic_large.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 3 to 413
# Data columns (total 19 columns):
# brandid                       48 non-null int64
# clientid                      48 non-null int64
# slug                          48 non-null object
# rawsize                       48 non-null float64
# total_number_of_spots_upld    1 non-null float64
# spot_duration                 3 non-null float64
# diffuse                       48 non-null object
# micro                         48 non-null object
# max_lag                       48 non-null float64
# lag_actions                   48 non-null float64
# jobpriority                   48 non-null float64
# workticket_duration           48 non-null float64
# last_job                      48 non-null object
# last_job_time                 48 non-null float64
# origin                        48 non-null object
# lag                           48 non-null object
# workticketid                  48 non-null object
# jobcount                      48 non-null int64
# cluster_info                  47 non-null object
# dtypes: float64(8), int64(3), object(8)
# memory usage: 7.5+ KB
#     brandid  clientid    slug       rawsize  total_number_of_spots_upld  \
# 3         1      1221   earny  9.382938e+08                         NaN
# 5         1      1337  hollar  2.360000e+11                         NaN
# 12        1      1221   earny  9.382938e+08                         NaN
# 18        1      1550    away  1.526642e+10                         NaN
# 24        1      1221   earny  9.382938e+08                         NaN
#
#     spot_duration diffuse micro  max_lag  lag_actions  jobpriority  \
# 3             NaN   False  True     14.0          4.0       1008.0
# 5             NaN    True  True     14.0          3.0       1008.0
# 12            NaN   False  True     14.0          4.0       1008.0
# 18            NaN    True  True     14.0          3.0       1008.0
# 24            NaN   False  True     14.0          4.0       1008.0
#
#     workticket_duration       last_job  last_job_time origin   lag  \
# 3           1617229.190  INF.SENDEMAIL          1.101  US(1)  True
# 5             19814.448  INF.SENDEMAIL          1.024  US(1)  True
# 12          1437263.068  INF.SENDEMAIL          1.016  US(1)  True
# 18          1437872.428  INF.SENDEMAIL          0.924  US(1)  True
# 24          1436105.480  INF.SENDEMAIL          1.208  US(1)  True
#
#                 workticketid  jobcount cluster_info
# 3   59a99475b43fdd01dc871a01         5    {u'1': 1}
# 5   59a9947cb43fdd01dc871a05         3          NaN
# 12  59ac5391b43fdd667ea9e226         5    {u'1': 1}
# 18  59ac5398b43fdd667ea9e232         5    {u'1': 1}
# 24  59ac5840b43fdd6dbddecb12         5    {u'1': 1}

# %%
# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1= plt.gca()

# create the data type to be entered in the graph
ax1.scatter(wkt_tic_large['rawsize'], wkt_tic_large['workticket_duration'], marker="o", color='b', label='workticket durration' )

# chart axes, title and legend
plt.title("workticket duration vs database size")
plt.ylabel("workticket duration")
plt.xlabel("database rawsize")
ax1.set_xscale('log')
ax1.axis([100000000, 2000000000000, -50000, 1000000])

# figure boundaries

plt.show()
