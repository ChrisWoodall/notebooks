# %% [markdown]
# This is a workflow for tidying the hollar data and adding the relevant total_sesion action data associated
# with the relevant day. Fortunately Hollar run their LOAD.SPOTS files consistently.
#
# With more complicated clients will need to do something more complicated

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('~/DataAnalysis/csv_files/client_specific_data_0110_0104/1337_current_all_data.csv')

dt_ts = pd.read_csv('~/DataAnalysis/csv_files/client_specific_data_0110_0104/client_1337_1_total_actions_per_day.csv')
dt_ts_sorted = dt_ts.sort_values(by="date")
print (dt_ts_sorted.dtypes)
dt_ts_sorted['date'] = pd.to_datetime(dt_ts_sorted['date'])
print (dt_ts_sorted.dtypes)
dt_ts_sorted
# Out:
# Unnamed: 0        int64
# date             object
# total_per_day     int64
# dtype: object
# Unnamed: 0                int64
# date             datetime64[ns]
# total_per_day             int64
# dtype: object
#     Unnamed: 0       date  total_per_day
# 32          32 2017-08-21          97615
# 5            5 2017-08-22          81086
# 46          46 2017-08-23          70373
# 4            4 2017-08-24          65179
# 36          36 2017-08-25          71353
# 25          25 2017-08-26          64605
# 0            0 2017-08-27          92115
# 18          18 2017-08-28          68162
# 44          44 2017-08-29          69001
# 37          37 2017-08-30          60359
# 13          13 2017-08-31          57438
# 28          28 2017-09-01          52466
# 49          49 2017-09-02          49014
# 7            7 2017-09-03          53006
# 30          30 2017-09-04          52508
# 40          40 2017-09-05          50013
# 11          11 2017-09-06          51820
# 21          21 2017-09-07          49104
# 35          35 2017-09-08          48048
# 3            3 2017-09-09          45560
# 16          16 2017-09-10          51796
# 39          39 2017-09-11          45869
# 43          43 2017-09-12          47037
# 17          17 2017-09-13          53045
# 27          27 2017-09-14          51690
# 47          47 2017-09-15         106802
# 12          12 2017-09-16          64537
# 23          23 2017-09-17         117787
# 42          42 2017-09-18          72632
# 1            1 2017-09-19          50000
# 24          24 2017-09-20          47119
# 34          34 2017-09-21          56357
# 2            2 2017-09-22          48989
# 14          14 2017-09-23          72388
# 29          29 2017-09-24          80581
# 48          48 2017-09-25          63379
# 8            8 2017-09-26          58924
# 33          33 2017-09-27          61167
# 41          41 2017-09-28          71883
# 9            9 2017-09-29          54680
# 22          22 2017-09-30          48844
# 26          26 2017-10-01          53448
# 31          31 2017-10-02          44521
# 6            6 2017-10-03          41176
# 38          38 2017-10-04          40279
# 15          15 2017-10-05          36405
# 19          19 2017-10-06          37891
# 45          45 2017-10-07          32869
# 20          20 2017-10-08          37075
# 10          10 2017-10-09          36020

# %%
df_trimmed =  df.drop(['Unnamed: 0','jobs', 'total_cost', 'total_time_in_queue', 
                         'total_time_under_calculation', 'total_time_waiting',
                         'total_time_waiting', 'total_time_under_calculation',
                         'total_cost','totalrowcount', 'spot_total', 
                         'spot_granularity_1', 
                         'workticket_scheduled', 'workticket_started', 'workticket_finished'], axis=1)
df_trimmed.head(15)
# Out:
#     brandid  clientid cluster_info  diffuse  jobcount  jobpriority   lag  \
# 0         1      1337    {u'2': 1}     True        42      1008.01  True
# 1         1      1337    {u'2': 1}     True        43      1008.01  True
# 2         1      1337    {u'2': 1}     True        41      1008.87  True
# 3         1      1337    {u'2': 1}     True        41      1008.87  True
# 4         1      1337    {u'2': 1}     True        41      1008.87  True
# 5         1      1337    {u'2': 1}     True        41      1008.87  True
# 6         1      1337    {u'2': 1}     True        42      1008.99  True
# 7         1      1337    {u'2': 1}     True        43      1009.88  True
# 8         1      1337    {u'2': 1}     True        44      1008.98  True
# 9         1      1337    {u'2': 1}     True        44      1008.98  True
# 10        1      1337    {u'2': 1}     True        43      1008.98  True
# 11        1      1337    {u'2': 1}     True        44      1008.01  True
# 12        1      1337    {u'2': 1}     True        42      1008.01  True
# 13        1      1337    {u'2': 1}     True        42      1008.98  True
# 14        1      1337    {u'2': 1}     True        42      1008.98  True
#
#     lag_actions       last_job  last_job_time            ...             \
# 0             3    INF.SCRUBDB          8.467            ...
# 1             3  INF.SENDEMAIL          0.787            ...
# 2             3    INF.SCRUBDB       4976.259            ...
# 3             3    INF.SCRUBDB       4976.259            ...
# 4             3    INF.SCRUBDB          4.301            ...
# 5             3    INF.SCRUBDB          4.301            ...
# 6             3    INF.SCRUBDB          4.077            ...
# 7             3  INF.SENDEMAIL          0.902            ...
# 8             3    INF.SCRUBDB       3402.323            ...
# 9             3    INF.SCRUBDB       3402.323            ...
# 10            3    INF.SCRUBDB       5244.146            ...
# 11            3  INF.SENDEMAIL          0.807            ...
# 12            3    INF.SCRUBDB       7712.427            ...
# 13            3    INF.SCRUBDB          3.161            ...
# 14            3    INF.SCRUBDB       4995.738            ...
#
#     micro  modelrowcount  origin       rawsize    slug spot_duration  \
# 0    True            123   US(1)  236000000000  hollar       86400.0
# 1    True           6140   US(1)  236000000000  hollar       86400.0
# 2    True           5709   US(1)  236000000000  hollar       86400.0
# 3    True           6808   US(1)  236000000000  hollar       86400.0
# 4    True            115   US(1)  236000000000  hollar       86400.0
# 5    True            107   US(1)  236000000000  hollar       86400.0
# 6    True           4844   US(1)  236000000000  hollar       86400.0
# 7    True           3902   US(1)  236000000000  hollar       86400.0
# 8    True           4764   US(1)  236000000000  hollar       86400.0
# 9    True            123   US(1)  236000000000  hollar       86400.0
# 10   True           4860   US(1)  236000000000  hollar       86400.0
# 11   True            109   US(1)  236000000000  hollar       86400.0
# 12   True           4453   US(1)  236000000000  hollar       86400.0
# 13   True           3708   US(1)  236000000000  hollar       86400.0
# 14   True           4942   US(1)  236000000000  hollar       86400.0
#
#                 spot_finish               spot_start workticket_duration  \
# 0   2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           28496.426
# 1   2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           16109.378
# 2   2017-09-30 00:00:00.000  2017-09-30 00:00:00.000           35398.932
# 3   2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           35525.145
# 4   2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           32855.169
# 5   2017-09-28 00:00:00.000  2017-09-28 00:00:00.000           32877.989
# 6   2017-09-13 00:00:00.000  2017-09-13 00:00:00.000           39356.100
# 7   2017-09-12 00:00:00.000  2017-09-12 00:00:00.000           67990.806
# 8   2017-09-11 00:00:00.000  2017-09-11 00:00:00.000           44098.867
# 9   2017-09-10 00:00:00.000  2017-09-10 00:00:00.000           46364.730
# 10  2017-09-19 00:00:00.000  2017-09-19 00:00:00.000           46916.144
# 11  2017-09-06 00:00:00.000  2017-09-06 00:00:00.000           32757.103
# 12  2017-09-14 00:00:00.000  2017-09-14 00:00:00.000           97835.631
# 13  2017-09-22 00:00:00.000  2017-09-22 00:00:00.000           24145.650
# 14  2017-09-20 00:00:00.000  2017-09-20 00:00:00.000           37781.086
#
#                 workticketid
# 0   59d3a993b712c904285d161d
# 1   59d272f5b43fdd11cf3755e7
# 2   59d14245b43fdd0bb470d7d8
# 3   59d13d95b43fdd02d38811ba
# 4   59cfdc0c28c9cb560cc59eeb
# 5   59cfdbf328c9cb560cc59ee9
# 6   59bab7f5b43fdd57c2ba341b
# 7   59b96673b43fdd4dc0032ed7
# 8   59b814f6b43fdd44596fb191
# 9   59b80c14b712c92ef3c6ad7a
# 10  59c2a0f4b43fdd23562b50e4
# 11  59b15dd33b34c922bac44205
# 12  59bc0976b43fdd57e1065d1a
# 13  59c80314b43fdd0a35c630df
# 14  59c3f273b43fdd27c543c49c
#
# [15 rows x 21 columns]

# %%
cols = df_trimmed.columns.tolist()

new_cols = []
new_cols.insert(0, 'cluster_info')
new_cols.insert(0, 'jobcount')
new_cols.insert(0, 'workticketid')
new_cols.insert(0, 'lag')
new_cols.insert(0, 'origin')
new_cols.insert(0, 'last_job_time')
new_cols.insert(0, 'last_job')
new_cols.insert(0, 'workticket_duration')
new_cols.insert(0, 'spot_finish')
new_cols.insert(0, 'spot_start')
new_cols.insert(0, 'jobpriority')
new_cols.insert(0, 'lag_actions')
new_cols.insert(0, 'max_lag')
new_cols.insert(0, 'micro')
new_cols.insert(0, 'diffuse')
new_cols.insert(0, 'spot_duration')
new_cols.insert(0, 'modelrowcount')
new_cols.insert(0, 'rawsize')
new_cols.insert(0, 'slug')
new_cols.insert(0, 'clientid')
new_cols.insert(0, 'brandid')

df_trimmed = df_trimmed[new_cols]
df_trimmed.head()
# Out:
#    brandid  clientid    slug       rawsize  modelrowcount  spot_duration  \
# 0        1      1337  hollar  236000000000            123        86400.0
# 1        1      1337  hollar  236000000000           6140        86400.0
# 2        1      1337  hollar  236000000000           5709        86400.0
# 3        1      1337  hollar  236000000000           6808        86400.0
# 4        1      1337  hollar  236000000000            115        86400.0
#
#    diffuse  micro  max_lag  lag_actions      ...       \
# 0     True   True       14            3      ...
# 1     True   True       14            3      ...
# 2     True   True       14            3      ...
# 3     True   True       14            3      ...
# 4     True   True       14            3      ...
#
#                 spot_start              spot_finish workticket_duration  \
# 0  2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           28496.426
# 1  2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           16109.378
# 2  2017-09-30 00:00:00.000  2017-09-30 00:00:00.000           35398.932
# 3  2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           35525.145
# 4  2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           32855.169
#
#         last_job last_job_time  origin   lag              workticketid  \
# 0    INF.SCRUBDB         8.467   US(1)  True  59d3a993b712c904285d161d
# 1  INF.SENDEMAIL         0.787   US(1)  True  59d272f5b43fdd11cf3755e7
# 2    INF.SCRUBDB      4976.259   US(1)  True  59d14245b43fdd0bb470d7d8
# 5         86400.0     True   True       14            3      ...
# 6         86400.0     True   True       14            3      ...
# 7         86400.0     True   True       14            3      ...
# 8         86400.0     True   True       14            3      ...
# 9         86400.0     True   True       14            3      ...
# 10        86400.0     True   True       14            3      ...
# 11        86400.0     True   True       14            3      ...
# 12        86400.0     True   True       14            3      ...
# 13        86400.0     True   True       14            3      ...
# 14        86400.0     True   True       14            3      ...
# 15        86400.0     True   True       14            3      ...
# 16        86400.0     True   True       14            3      ...
# 17        86400.0     True   True       14            3      ...
# 18        86400.0     True   True       14            3      ...
# 19        86400.0     True   True       14            3      ...
# 20        86400.0     True   True       14            3      ...
# 21        86400.0     True   True       14            3      ...
# 22        86400.0     True   True       14            3      ...
# 23        86400.0     True   True       14            3      ...
# 24        86400.0     True   True       14            3      ...
# 25        86400.0     True   True       14            3      ...
# 26        86400.0     True   True       14            3      ...
# 27        86400.0     True   True       14            3      ...
# 28        86400.0     True   True       14            3      ...
# 29        86400.0     True   True       14            3      ...
# 30        86400.0     True   True       14            3      ...
# 31        86400.0     True   True       14            3      ...
# 32        86400.0     True   True       14            3      ...
# 33        86400.0     True   True       14            3      ...
# 34        86400.0     True   True       14            3      ...
# 35        86400.0     True   True       14            3      ...
# 36        86400.0     True   True       14            3      ...
# 37        86400.0     True   True       14            3      ...
# 38        86400.0     True   True       14            3      ...
# 39        86400.0     True   True       14            3      ...
# 40        86400.0     True   True       14            3      ...
# 41        86400.0     True   True       14            3      ...
# 42        86400.0     True   True       14            3      ...
# 43        86400.0     True   True       14            3      ...
# 44        86400.0     True   True       14            3      ...
# 45        86400.0     True   True       14            3      ...
# 46        86400.0     True   True       14            3      ...
# 47        86400.0     True   True       14            3      ...
# 48        86400.0     True   True       14            3      ...
# 49        86400.0     True   True       14            3      ...
#
#                  spot_start              spot_finish workticket_duration  \
# 0   2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           28496.426
# 1   2017-10-01 00:00:00.000  2017-10-01 00:00:00.000           16109.378
# 2   2017-09-30 00:00:00.000  2017-09-30 00:00:00.000           35398.932
# 3   2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           35525.145
# 4   2017-09-29 00:00:00.000  2017-09-29 00:00:00.000           32855.169
# 5   2017-09-28 00:00:00.000  2017-09-28 00:00:00.000           32877.989
# 6   2017-09-13 00:00:00.000  2017-09-13 00:00:00.000           39356.100
# 7   2017-09-12 00:00:00.000  2017-09-12 00:00:00.000           67990.806
# 8   2017-09-11 00:00:00.000  2017-09-11 00:00:00.000           44098.867
# 9   2017-09-10 00:00:00.000  2017-09-10 00:00:00.000           46364.730
# 10  2017-09-19 00:00:00.000  2017-09-19 00:00:00.000           46916.144
# 11  2017-09-06 00:00:00.000  2017-09-06 00:00:00.000           32757.103
# 12  2017-09-14 00:00:00.000  2017-09-14 00:00:00.000           97835.631
# 13  2017-09-22 00:00:00.000  2017-09-22 00:00:00.000           24145.650
# 14  2017-09-20 00:00:00.000  2017-09-20 00:00:00.000           37781.086
# 15  2017-09-11 00:00:00.000  2017-09-11 00:00:00.000           46347.665
# 16  2017-09-07 00:00:00.000  2017-09-07 00:00:00.000           24949.409
# 6     INF.SCRUBDB         4.077   US(1)  True  59bab7f5b43fdd57c2ba341b
# 7   INF.SENDEMAIL         0.902   US(1)  True  59b96673b43fdd4dc0032ed7
# 8     INF.SCRUBDB      3402.323   US(1)  True  59b814f6b43fdd44596fb191
# 9     INF.SCRUBDB      3402.323   US(1)  True  59b80c14b712c92ef3c6ad7a
# 10    INF.SCRUBDB      5244.146   US(1)  True  59c2a0f4b43fdd23562b50e4
# 11  INF.SENDEMAIL         0.807   US(1)  True  59b15dd33b34c922bac44205
# 12    INF.SCRUBDB      7712.427   US(1)  True  59bc0976b43fdd57e1065d1a
# 13    INF.SCRUBDB         3.161   US(1)  True  59c80314b43fdd0a35c630df
# 14    INF.SCRUBDB      4995.738   US(1)  True  59c3f273b43fdd27c543c49c
# 15    INF.SCRUBDB      3402.323   US(1)  True  59b80c2dc6d4312db328c4e4
# 16    INF.SCRUBDB      2311.234   US(1)  True  59b2cef8b43fdd7ab725f9a3
# 17    INF.SCRUBDB      3402.323   US(1)  True  59b80b8eb43fdd3691c632ab
# 18    INF.SCRUBDB      3475.738   US(1)  True  59a99480b43fdd01dc871a07
# 19  INF.SENDEMAIL         0.811   US(1)  True  59b99c259869ab4637ebbacb
# 20  INF.SENDEMAIL         0.819   US(1)  True  59b17d74b43fdd4232abdece
# 21    INF.SCRUBDB      3402.323   US(1)  True  59b80bd0c6d4312db328c4e2
# 22    INF.SCRUBDB         4.077   US(1)  True  59baacf5561f8342dce87d00
# 23  INF.SENDEMAIL         0.805   US(1)  True  59b15db8c6d43120a74c6b94
# 24    INF.SCRUBDB      2012.452   US(1)  True  59bec894b43fdd591704bbdc
# 25    INF.SCRUBDB      7712.427   US(1)  True  59bbe3363b34c905838d10d3
# 26    INF.SCRUBDB      3402.323   US(1)  True  59b80bfc3b34c92fb48d10a7
# 27  INF.SENDEMAIL         0.798   US(1)  True  59bffdf1b43fdd3834355ad7
# 28    INF.SCRUBDB         9.968   US(1)  True  59cc1df85ad0b3054df6e62b
# 29    INF.SCRUBDB         3.360   US(1)  True  59b6c81fb43fdd63b520bc01
# 30    INF.SCRUBDB         8.467   US(1)  True  59d3a9818a8845042edc6761
# 31  INF.SENDEMAIL         0.779   US(1)  True  59b02bf6b43fdd449c9a47c7
# 32    INF.SCRUBDB      2012.452   US(1)  True  59be999bc6e39c7ef867a2f6
# 33  INF.SENDEMAIL         0.782   US(1)  True  59c93874b43fdd352df809d8
# 34    INF.SCRUBDB      2012.452   US(1)  True  59be99bac6e39c7ef867a2f8
# 35    INF.SCRUBDB         3.161   US(1)  True  59c807c1b43fdd1131bc8655
# 36  INF.SENDEMAIL         0.784   US(1)  True  59becd44b43fdd601fd63965
# 37  INF.SENDEMAIL         0.835   US(1)  True  59c1b8e8b43fdd32bc887208
# 38  INF.SENDEMAIL         0.796   US(1)  True  59b15da23b34c922bbc4422e
# 39  INF.SENDEMAIL         1.860   US(1)  True  59c16448561f8370ffe87c67
# 40  INF.SENDEMAIL         1.582   US(1)  True  59b6c378b43fdd5ccbadac32
# 41  INF.SENDEMAIL         0.966   US(1)  True  59c543f5b43fdd24a8215203
# 42    INF.SCRUBDB      3475.738   US(1)  True  59a99276702f070432a80404
# 43  INF.SENDEMAIL         1.550   US(1)  True  59ce7e76b43fdd40a047eff6
# 44    INF.SCRUBDB      4456.583   US(1)  True  59ca89f3b43fdd6ccb9e7424
# 45    INF.SCRUBDB      4456.583   US(1)  True  59cade5a5ad0b3042965cfb7
# 46    INF.SCRUBDB         9.968   US(1)  True  59cbdb77b43fdd10669a27f4
# 47    INF.SCRUBDB         9.968   US(1)  True  59cc1de55ad0b3054df6e629
# 48  INF.SENDEMAIL         0.799   US(1)  True  59cd2cf7b43fdd574612dc02
# 49  INF.SENDEMAIL         0.851   US(1)  True  59cd383d2f4dd3058713599a
#
#    jobcount  cluster_info
# 0        42     {u'2': 1}
# 1        43     {u'2': 1}
# 2        41     {u'2': 1}
# 3        41     {u'2': 1}
# 4        41     {u'2': 1}
# 5        41     {u'2': 1}
# 6        42     {u'2': 1}
# 7        43     {u'2': 1}
# 8        44     {u'2': 1}
# 9        44     {u'2': 1}
# 10       43     {u'2': 1}
# 11       44     {u'2': 1}
# 12       42     {u'2': 1}
# 13       42     {u'2': 1}
# 14       42     {u'2': 1}
# 15       44     {u'2': 1}
# 16       42     {u'2': 1}
# 17       44     {u'2': 1}
# 18       49           NaN
# 19       43     {u'2': 1}
# 20       43     {u'2': 1}
# 21       44     {u'2': 1}
# 22       42     {u'2': 1}
# 23       44     {u'2': 1}
# 24       42     {u'2': 1}
# 25       43     {u'2': 1}
# 26       44     {u'2': 1}
# 27       42     {u'2': 1}
# 28       41     {u'2': 1}
# 29       42     {u'2': 1}
# 30       42     {u'2': 1}
# 31       43     {u'2': 1}
# 32       43     {u'2': 1}
# 33       42     {u'2': 1}
# 34       43     {u'2': 1}
# 35       42     {u'2': 1}
# 36       42     {u'2': 1}
# 37       43     {u'2': 1}
# 38       44     {u'2': 1}
# 39       42     {u'2': 1}
# 40       42     {u'2': 1}
# 41       43     {u'2': 1}
# 42       49           NaN
# 43       41     {u'2': 1}
# 44       42     {u'2': 1}
# 45       41     {u'2': 1}
# 46       41     {u'2': 1}
# 47       41     {u'2': 1}
# 48       41     {u'2': 1}
# 49       41     {u'2': 1}
#
# [50 rows x 21 columns]

# %%
temp = pd.DatetimeIndex(rename['spot_start'])
print (temp.dtype)
rename['spot_start_date'] = temp.date
rename['spot_start_time'] = temp.time
rename['spot_start_date'] = pd.to_datetime(rename['spot_start_date'])

print (rename.dtypes)

# rename['spot_start_time'], rename['spot_start_date'] = rename['spot_start_date'].apply(lambda x:x.time()), rename['spot_start_date'].apply(lambda x:x.date())

# df = pd.DataFrame({'Date':['2014-07-17 00:59:27.400189+00']})
# df['Date'] = pd.to_datetime(df['Date'])
# df['Time'],df['Date']= df['Date'].apply(lambda x:x.time()), df['Date'].apply(lambda x:x.date())
# df
# Out:
# datetime64[ns]
# brandid                           int64
# clientid                          int64
# slug                             object
# rawsize                           int64
# total_number_of_spots             int64
# spot_duration                   float64
# diffuse                            bool
# micro                              bool
# max_lag                           int64
# lag_actions                       int64
# jobpriority                     float64
# spot_start                       object
# spot_finish                      object
# workticket_duration             float64
# last_job                         object
# last_job_time                   float64
# origin                           object
# lag                                bool
# workticketid                     object
# jobcount                          int64
# cluster_info                     object
# spot_start_date          datetime64[ns]
# spot_start_time                  object
# dtype: object

# %%
rename_sorted = rename.sort_values(by="spot_start_date")
rename_sorted.drop(['spot_start'], axis=1)
rename_sorted.head(5)
# Out:
#     brandid  clientid    slug       rawsize  total_number_of_spots  \
# 42        1      1337  hollar  236000000000                    105
# 18        1      1337  hollar  236000000000                   5183
# 38        1      1337  hollar  236000000000                    119
# 31        1      1337  hollar  236000000000                   4767
# 23        1      1337  hollar  236000000000                    115
#
#     spot_duration  diffuse  micro  max_lag  lag_actions       ...         \
# 42        86400.0     True   True       14            3       ...
# 18        86400.0     True   True       14            3       ...
# 38        86400.0     True   True       14            3       ...
# 31        86400.0     True   True       14            3       ...
# 23        86400.0     True   True       14            3       ...
#
#     workticket_duration       last_job last_job_time  origin   lag  \
# 42            61474.414    INF.SCRUBDB      3475.738   US(1)  True
# 18            60955.424    INF.SCRUBDB      3475.738   US(1)  True
# 38            32812.622  INF.SENDEMAIL         0.796   US(1)  True
# 31            16722.584  INF.SENDEMAIL         0.779   US(1)  True
# 23            32782.520  INF.SENDEMAIL         0.805   US(1)  True
#
#                 workticketid jobcount  cluster_info spot_start_date  \
# 42  59a99276702f070432a80404       49           NaN      2017-08-31
# 18  59a99480b43fdd01dc871a07       49           NaN      2017-08-31
# 38  59b15da23b34c922bbc4422e       44     {u'2': 1}      2017-09-04
# 31  59b02bf6b43fdd449c9a47c7       43     {u'2': 1}      2017-09-05
# 23  59b15db8c6d43120a74c6b94       44     {u'2': 1}      2017-09-05
#
#     spot_start_time
# 42         00:00:00
# 18         00:00:00
# 38         00:00:00
# 31         00:00:00
# 23         00:00:00
#
# [5 rows x 23 columns]

# %%
# merged = pd.merge(rename_sorted, data2, by="datetime")

# merged = pd.merge(rename_sorted, dt_ts_sorted, on='date', how='outer')

#merged = pd.merge_asof(rename_sorted, dt_ts_sorted, on='spot_start_date', by="total_per_day")
# print (rename_sorted.columns, rename_sorted.dtypes)
# print (dt_ts_sorted.columns, dt_ts_sorted.dtypes)
rename_sorted['date'] = rename_sorted['spot_start_date']
# dt_ts_sorted.columns


merged  = pd.merge(rename_sorted, dt_ts_sorted)
merged.head()
# Out:
#    brandid  clientid    slug       rawsize  total_number_of_spots  \
# 0        1      1337  hollar  236000000000                    105
# 1        1      1337  hollar  236000000000                   5183
# 2        1      1337  hollar  236000000000                    119
# 3        1      1337  hollar  236000000000                   4767
# 4        1      1337  hollar  236000000000                    115
#
#    spot_duration  diffuse  micro  max_lag  lag_actions      ...        origin  \
# 0        86400.0     True   True       14            3      ...         US(1)
# 1        86400.0     True   True       14            3      ...         US(1)
# 2        86400.0     True   True       14            3      ...         US(1)
# 3        86400.0     True   True       14            3      ...         US(1)
# 4        86400.0     True   True       14            3      ...         US(1)
#
#     lag              workticketid  jobcount cluster_info  spot_start_date  \
# 0  True  59a99276702f070432a80404        49          NaN       2017-08-31
# 1  True  59a99480b43fdd01dc871a07        49          NaN       2017-08-31
# 2  True  59b15da23b34c922bbc4422e        44    {u'2': 1}       2017-09-04
# 5         86400.0     True   True       14            3
# 6         86400.0     True   True       14            3
# 7         86400.0     True   True       14            3
# 8         86400.0     True   True       14            3
# 9         86400.0     True   True       14            3
# 10        86400.0     True   True       14            3
# 11        86400.0     True   True       14            3
# 12        86400.0     True   True       14            3
# 13        86400.0     True   True       14            3
# 14        86400.0     True   True       14            3
# 15        86400.0     True   True       14            3
# 16        86400.0     True   True       14            3
# 17        86400.0     True   True       14            3
# 18        86400.0     True   True       14            3
# 19        86400.0     True   True       14            3
# 20        86400.0     True   True       14            3
# 21        86400.0     True   True       14            3
# 22        86400.0     True   True       14            3
# 23        86400.0     True   True       14            3
# 24        86400.0     True   True       14            3
# 25        86400.0     True   True       14            3
# 26        86400.0     True   True       14            3
# 27        86400.0     True   True       14            3
# 28        86400.0     True   True       14            3
# 29        86400.0     True   True       14            3
# 30        86400.0     True   True       14            3
# 31        86400.0     True   True       14            3
# 32        86400.0     True   True       14            3
# 33        86400.0     True   True       14            3
# 34        86400.0     True   True       14            3
# 35        86400.0     True   True       14            3
# 36        86400.0     True   True       14            3
# 37        86400.0     True   True       14            3
# 38        86400.0     True   True       14            3
# 39        86400.0     True   True       14            3
# 40        86400.0     True   True       14            3
# 41        86400.0     True   True       14            3
# 42        86400.0     True   True       14            3
# 43        86400.0     True   True       14            3
# 44        86400.0     True   True       14            3
# 45        86400.0     True   True       14            3
# 46        86400.0     True   True       14            3
# 47        86400.0     True   True       14            3
# 48        86400.0     True   True       14            3
# 49        86400.0     True   True       14            3
#
#             ...                        spot_finish workticket_duration  \
# 0           ...            2017-08-31 00:00:00.000           61474.414
# 1           ...            2017-08-31 00:00:00.000           60955.424
# 2           ...            2017-09-04 00:00:00.000           32812.622
# 3           ...            2017-09-05 00:00:00.000           16722.584
# 4           ...            2017-09-05 00:00:00.000           32782.520
# 5           ...            2017-09-06 00:00:00.000           32757.103
# 6           ...            2017-09-06 00:00:00.000           32751.798
# 7           ...            2017-09-07 00:00:00.000           24949.409
# 8           ...            2017-09-08 00:00:00.000           46439.455
# 9           ...            2017-09-08 00:00:00.000           46507.145
# 10          ...            2017-09-09 00:00:00.000           25640.735
# 11          ...            2017-09-09 00:00:00.000           46394.824
# 12          ...            2017-09-10 00:00:00.000           26825.903
# 13          ...            2017-09-10 00:00:00.000           46364.730
# 14          ...            2017-09-11 00:00:00.000           44098.867
# 15          ...            2017-09-11 00:00:00.000           46347.665
# 16          ...            2017-09-12 00:00:00.000           67901.359
# 17          ...            2017-09-12 00:00:00.000           67990.806
# 18          ...            2017-09-13 00:00:00.000           39356.100
# 19          ...            2017-09-13 00:00:00.000           41555.888
# 20          ...            2017-09-14 00:00:00.000           97835.631
# 21          ...            2017-09-14 00:00:00.000           99194.574
# 22          ...            2017-09-15 00:00:00.000           31356.441
# 23          ...            2017-09-15 00:00:00.000           31296.591
# 24          ...            2017-09-16 00:00:00.000           31326.342
# 25          ...            2017-09-16 00:00:00.000           31296.591
# 26          ...            2017-09-17 00:00:00.000           20190.742
# 27          ...            2017-09-17 00:00:00.000           18477.788
# 28          ...            2017-09-18 00:00:00.000           24344.460
# 29          ...            2017-09-19 00:00:00.000           46916.144
# 30          ...            2017-09-20 00:00:00.000           37781.086
# 31          ...            2017-09-21 00:00:00.000           28332.049
# 32          ...            2017-09-22 00:00:00.000           24145.650
# 33          ...            2017-09-23 00:00:00.000           24093.632
# 34          ...            2017-09-24 00:00:00.000           15392.029
# 35          ...            2017-09-25 00:00:00.000           37903.022
# 36          ...            2017-09-25 00:00:00.000           44357.147
# 37          ...            2017-09-25 00:00:00.000           44281.522
# 38          ...            2017-09-26 00:00:00.000           37962.726
# 39          ...            2017-09-26 00:00:00.000           37903.022
# 40          ...            2017-09-27 00:00:00.000           20622.796
# 41          ...            2017-09-27 00:00:00.000           20680.404
# 42          ...            2017-09-28 00:00:00.000           32877.989
# 43          ...            2017-09-28 00:00:00.000           21295.480
# 44          ...            2017-09-29 00:00:00.000           32855.169
# 45          ...            2017-09-29 00:00:00.000           35525.145
# 46          ...            2017-09-30 00:00:00.000           35398.932
# 47          ...            2017-09-30 00:00:00.000           28501.671
# 48          ...            2017-10-01 00:00:00.000           16109.378
# 49          ...            2017-10-01 00:00:00.000           28496.426
#
#          last_job  last_job_time origin   lag              workticketid  \
# 0     INF.SCRUBDB       3475.738  US(1)  True  59a99276702f070432a80404
# 1     INF.SCRUBDB       3475.738  US(1)  True  59a99480b43fdd01dc871a07
# 2   INF.SENDEMAIL          0.796  US(1)  True  59b15da23b34c922bbc4422e
# 3   INF.SENDEMAIL          0.779  US(1)  True  59b02bf6b43fdd449c9a47c7
# 4   INF.SENDEMAIL          0.805  US(1)  True  59b15db8c6d43120a74c6b94
# 5   INF.SENDEMAIL          0.807  US(1)  True  59b15dd33b34c922bac44205
# 6   INF.SENDEMAIL          0.819  US(1)  True  59b17d74b43fdd4232abdece
# 7     INF.SCRUBDB       2311.234  US(1)  True  59b2cef8b43fdd7ab725f9a3
# 8     INF.SCRUBDB       3402.323  US(1)  True  59b80bd0c6d4312db328c4e2
# 9     INF.SCRUBDB       3402.323  US(1)  True  59b80b8eb43fdd3691c632ab
# 10    INF.SCRUBDB          3.360  US(1)  True  59b6c81fb43fdd63b520bc01
# 11    INF.SCRUBDB       3402.323  US(1)  True  59b80bfc3b34c92fb48d10a7
# 12  INF.SENDEMAIL          1.582  US(1)  True  59b6c378b43fdd5ccbadac32
# 13    INF.SCRUBDB       3402.323  US(1)  True  59b80c14b712c92ef3c6ad7a
# 14    INF.SCRUBDB       3402.323  US(1)  True  59b814f6b43fdd44596fb191
# 15    INF.SCRUBDB       3402.323  US(1)  True  59b80c2dc6d4312db328c4e4
# 16  INF.SENDEMAIL          0.811  US(1)  True  59b99c259869ab4637ebbacb
# 17  INF.SENDEMAIL          0.902  US(1)  True  59b96673b43fdd4dc0032ed7
# 18    INF.SCRUBDB          4.077  US(1)  True  59bab7f5b43fdd57c2ba341b
# 19    INF.SCRUBDB          4.077  US(1)  True  59baacf5561f8342dce87d00
# 20    INF.SCRUBDB       7712.427  US(1)  True  59bc0976b43fdd57e1065d1a
# 21    INF.SCRUBDB       7712.427  US(1)  True  59bbe3363b34c905838d10d3
# 22    INF.SCRUBDB       2012.452  US(1)  True  59be999bc6e39c7ef867a2f6
# 23    INF.SCRUBDB       2012.452  US(1)  True  59bec894b43fdd591704bbdc
# 24    INF.SCRUBDB       2012.452  US(1)  True  59be99bac6e39c7ef867a2f8
# 25  INF.SENDEMAIL          0.784  US(1)  True  59becd44b43fdd601fd63965
# 26  INF.SENDEMAIL          0.798  US(1)  True  59bffdf1b43fdd3834355ad7
# 27  INF.SENDEMAIL          1.860  US(1)  True  59c16448561f8370ffe87c67
# 28  INF.SENDEMAIL          0.835  US(1)  True  59c1b8e8b43fdd32bc887208
# 29    INF.SCRUBDB       5244.146  US(1)  True  59c2a0f4b43fdd23562b50e4
# 30    INF.SCRUBDB       4995.738  US(1)  True  59c3f273b43fdd27c543c49c
# 31  INF.SENDEMAIL          0.966  US(1)  True  59c543f5b43fdd24a8215203
# 32    INF.SCRUBDB          3.161  US(1)  True  59c80314b43fdd0a35c630df
# 33    INF.SCRUBDB          3.161  US(1)  True  59c807c1b43fdd1131bc8655
# 34  INF.SENDEMAIL          0.782  US(1)  True  59c93874b43fdd352df809d8
# 35    INF.SCRUBDB          9.968  US(1)  True  59cc1df85ad0b3054df6e62b
# 36    INF.SCRUBDB       4456.583  US(1)  True  59ca89f3b43fdd6ccb9e7424
# 37    INF.SCRUBDB       4456.583  US(1)  True  59cade5a5ad0b3042965cfb7
# 38    INF.SCRUBDB          9.968  US(1)  True  59cbdb77b43fdd10669a27f4
# 39    INF.SCRUBDB          9.968  US(1)  True  59cc1de55ad0b3054df6e629
# 40  INF.SENDEMAIL          0.851  US(1)  True  59cd383d2f4dd3058713599a
# 41  INF.SENDEMAIL          0.799  US(1)  True  59cd2cf7b43fdd574612dc02
# 42    INF.SCRUBDB          4.301  US(1)  True  59cfdbf328c9cb560cc59ee9
# 43  INF.SENDEMAIL          1.550  US(1)  True  59ce7e76b43fdd40a047eff6
# 44    INF.SCRUBDB          4.301  US(1)  True  59cfdc0c28c9cb560cc59eeb
# 45    INF.SCRUBDB       4976.259  US(1)  True  59d13d95b43fdd02d38811ba
# 46    INF.SCRUBDB       4976.259  US(1)  True  59d14245b43fdd0bb470d7d8
# 47    INF.SCRUBDB          8.467  US(1)  True  59d3a9818a8845042edc6761
# 48  INF.SENDEMAIL          0.787  US(1)  True  59d272f5b43fdd11cf3755e7
# 49    INF.SCRUBDB          8.467  US(1)  True  59d3a993b712c904285d161d
#
#     jobcount spot_start_date  total_session_actions
# 0         49      2017-08-31                  57438
# 1         49      2017-08-31                  57438
# 2         44      2017-09-04                  52508
# 3         43      2017-09-05                  50013
# 4         44      2017-09-05                  50013
# 5         44      2017-09-06                  51820
# 6         43      2017-09-06                  51820
# 7         42      2017-09-07                  49104
# 8         44      2017-09-08                  48048
# 9         44      2017-09-08                  48048
# 10        42      2017-09-09                  45560
# 11        44      2017-09-09                  45560
# 12        42      2017-09-10                  51796
# 13        44      2017-09-10                  51796
# 14        44      2017-09-11                  45869
# 15        44      2017-09-11                  45869
# 16        43      2017-09-12                  47037
# 17        43      2017-09-12                  47037
# 18        42      2017-09-13                  53045
# 19        42      2017-09-13                  53045
# 20        42      2017-09-14                  51690
# 21        43      2017-09-14                  51690
# 22        43      2017-09-15                 106802
# 23        42      2017-09-15                 106802
# 24        43      2017-09-16                  64537
# 25        42      2017-09-16                  64537
# 26        42      2017-09-17                 117787
# 27        42      2017-09-17                 117787
# 28        43      2017-09-18                  72632
# 29        43      2017-09-19                  50000
# 30        42      2017-09-20                  47119
# 31        43      2017-09-21                  56357
# 32        42      2017-09-22                  48989
# 33        42      2017-09-23                  72388
# 34        42      2017-09-24                  80581
# 35        41      2017-09-25                  63379
# 36        42      2017-09-25                  63379
# 37        41      2017-09-25                  63379
# 38        41      2017-09-26                  58924
# 39        41      2017-09-26                  58924
# 40        41      2017-09-27                  61167
# 41        41      2017-09-27                  61167
# 42        41      2017-09-28                  71883
# 43        41      2017-09-28                  71883
# 44        41      2017-09-29                  54680
# 45        41      2017-09-29                  54680
# 46        41      2017-09-30                  48844
# 47        42      2017-09-30                  48844
# 48        43      2017-10-01                  53448
# 49        42      2017-10-01                  53448
#
# [50 rows x 22 columns]

# %%
clean.head()
# Out:
#    brandid  clientid    slug       rawsize  total_number_of_spots  \
# 0        1      1337  hollar  236000000000                    105
# 1        1      1337  hollar  236000000000                   5183
# 2        1      1337  hollar  236000000000                    119
# 3        1      1337  hollar  236000000000                   4767
# 4        1      1337  hollar  236000000000                    115
#
#    spot_duration  diffuse  micro  max_lag  lag_actions          ...            \
# 0        86400.0     True   True       14            3          ...
# 1        86400.0     True   True       14            3          ...
# 2        86400.0     True   True       14            3          ...
# 3        86400.0     True   True       14            3          ...
# 4        86400.0     True   True       14            3          ...
#
#                spot_finish workticket_duration       last_job  last_job_time  \
# 0  2017-08-31 00:00:00.000           61474.414    INF.SCRUBDB       3475.738
# 1  2017-08-31 00:00:00.000           60955.424    INF.SCRUBDB       3475.738
# 2  2017-09-04 00:00:00.000           32812.622  INF.SENDEMAIL          0.796
# 3  2017-09-05 00:00:00.000           16722.584  INF.SENDEMAIL          0.779
# 4  2017-09-05 00:00:00.000           32782.520  INF.SENDEMAIL          0.805
#
#   origin   lag              workticketid  jobcount spot_start_date  \
# 0  US(1)  True  59a99276702f070432a80404        49      2017-08-31
# 1  US(1)  True  59a99480b43fdd01dc871a07        49      2017-08-31
# 2  US(1)  True  59b15da23b34c922bbc4422e        44      2017-09-04
# 3  US(1)  True  59b02bf6b43fdd449c9a47c7        43      2017-09-05
# 4  US(1)  True  59b15db8c6d43120a74c6b94        44      2017-09-05
#
#    total_session_actions
# 0                  57438
# 1                  57438
# 2                  52508
# 3                  50013
# 4                  50013
#
# [5 rows x 22 columns]

# %%
# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1= plt.gca()

# create the data type to be entered in the graph
ax1.scatter(clean['total_session_actions'], clean['workticket_duration'], marker="o", color='b', label='workticket durration' )

# chart axes, title and legend
plt.title("workticket duration vs total_session_actions_per_day")
plt.ylabel("workticket duration")
plt.xlabel("total_session_actions")
ax1.axis([40000,90000 , -100, 120000])

# figure boundaries

plt.show()

# %%
# create a figure

# create the data type to be entered in the graph
plt.scatter(clean['total_number_of_spots'], clean['workticket_duration'], marker="o", color='b', label='workticket durration' )



plt.show()

# %%
this
