# %%
# This is my scratch pad for large dataanalysis for the jobqueue data sets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# I am going to import the large dataset as a csv and use pandas to process
#
# By changing the header value here to 0, I can set the first value of the csv as header of the table

# %%
df = pd.read_csv('~/Dev/tvsquared-backend/tvsquared/tmp/cw/all_details_current.csv', header=0)

# %%
df
# Out:
#       Unnamed: 0  brandid  clientid     cluster_info diffuse  jobcount  \
# 0              0        1      1594        {u'3': 1}    True        52
# 1              1        1      1558        {u'1': 1}   False        42
# 2              2        1      1557        {u'1': 1}   False        42
# 3              3        1      1557        {u'1': 1}   False        42
# 4              4        1      1558        {u'1': 1}   False        39
# 5              5        1      1558        {u'1': 1}   False        39
# 6              6        1      1557        {u'1': 1}   False        39
# 7              7        2       952        {u'4': 1}   False        40
# 8              8        1      1558        {u'1': 1}   False        39
# 9              9        1      1558        {u'1': 1}   False        39
# 10            10        2       952        {u'4': 1}   False        41
# 11            11        2       952        {u'4': 1}   False        40
# ...

# %% [markdown]
# ok, now I want to trim out the cells that I dont want.
#
# I think that to remove a column it is done like
# df.drop("Column", axis=1)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2063 entries, 0 to 2062
# Data columns (total 33 columns):
# Unnamed: 0                      2063 non-null int64
# brandid                         2063 non-null int64
# clientid                        2063 non-null int64
# cluster_info                    2061 non-null object
# diffuse                         2035 non-null object
# jobcount                        2063 non-null int64
# jobpriority                     2063 non-null float64
# jobs                            2063 non-null object
# lag                             2035 non-null object
# lag_actions                     2035 non-null float64
# last_job                        2063 non-null object
# last_job_time                   2063 non-null float64
# max_lag                         2035 non-null float64
# micro                           2035 non-null object
# modelrowcount                   2063 non-null int64
# origin                          2035 non-null object
# ...

# %%
df.drop('jobs', axis=1)
# Out:
#       Unnamed: 0  brandid  clientid     cluster_info diffuse  jobcount  \
# 0              0        1      1594        {u'3': 1}    True        52
# 1              1        1      1558        {u'1': 1}   False        42
# 2              2        1      1557        {u'1': 1}   False        42
# 3              3        1      1557        {u'1': 1}   False        42
# 4              4        1      1558        {u'1': 1}   False        39
# 5              5        1      1558        {u'1': 1}   False        39
# 6              6        1      1557        {u'1': 1}   False        39
# 7              7        2       952        {u'4': 1}   False        40
# 8              8        1      1558        {u'1': 1}   False        39
# 9              9        1      1558        {u'1': 1}   False        39
# 10            10        2       952        {u'4': 1}   False        41
# 11            11        2       952        {u'4': 1}   False        40
# ...

# %% [markdown]
# Ok, I want to learn how to make the column titles equal to the values in the 0 row

# %%
df.drop([0])
# Out:
#       Unnamed: 0  brandid  clientid     cluster_info diffuse  jobcount  \
# 1              1        1      1558        {u'1': 1}   False        42
# 2              2        1      1557        {u'1': 1}   False        42
# 3              3        1      1557        {u'1': 1}   False        42
# 4              4        1      1558        {u'1': 1}   False        39
# 5              5        1      1558        {u'1': 1}   False        39
# 6              6        1      1557        {u'1': 1}   False        39
# 7              7        2       952        {u'4': 1}   False        40
# 8              8        1      1558        {u'1': 1}   False        39
# 9              9        1      1558        {u'1': 1}   False        39
# 10            10        2       952        {u'4': 1}   False        41
# 11            11        2       952        {u'4': 1}   False        40
# 12            12        2       952        {u'4': 1}   False        41
# ...

# %% [markdown]
# dropping lots of columns at oncecan be done by specifing multiple columns i believe

# %%
df_trimmed =  df.drop(['Unnamed: 0','jobs', 'total_cost', 'total_time_in_queue', 
                         'total_time_under_calculation', 'total_time_waiting',
                         'total_time_waiting', 'total_time_under_calculation',
                         'total_cost', 'spot_finish','totalrowcount', 'spot_total', 
                         'spot_start', 'spot_granularity_1', 
                         'workticket_scheduled', 'workticket_started', 'workticket_finished'], axis=1)

df_trimmed
# Out:
#       brandid  clientid     cluster_info diffuse  jobcount  jobpriority  \
# 0           1      1594        {u'3': 1}    True        52      5008.98
# 1           1      1558        {u'1': 1}   False        42      1008.01
# 2           1      1557        {u'1': 1}   False        42      1008.01
# 3           1      1557        {u'1': 1}   False        42      1008.01
# 4           1      1558        {u'1': 1}   False        39      1008.01
# 5           1      1558        {u'1': 1}   False        39      1008.01
# 6           1      1557        {u'1': 1}   False        39      1008.01
# 7           2       952        {u'4': 1}   False        40      1008.01
# 8           1      1558        {u'1': 1}   False        39      1008.01
# 9           1      1558        {u'1': 1}   False        39      1008.01
# 10          2       952        {u'4': 1}   False        41      1008.01
# 11          2       952        {u'4': 1}   False        40      1008.01
# ...

# %%
cols = df_trimmed.columns.tolist()

new_cols = []
new_cols.insert(0, 'cluster_info')
new_cols.insert(0, 'jobcount')
new_cols.insert(0, 'workticketid')
new_cols.insert(0, 'lag')
new_cols.insert(0, 'origin')
new_cols.insert(0, 'last_job_time')
new_cols.insert(0, 'last_job')
new_cols.insert(0, 'workticket_duration')
new_cols.insert(0, 'jobpriority')
new_cols.insert(0, 'lag_actions')
new_cols.insert(0, 'max_lag')
new_cols.insert(0, 'micro')
new_cols.insert(0, 'diffuse')
new_cols.insert(0, 'spot_duration')
new_cols.insert(0, 'modelrowcount')
new_cols.insert(0, 'rawsize')
new_cols.insert(0, 'slug')
new_cols.insert(0, 'clientid')
new_cols.insert(0, 'brandid')

df_trimmed = df_trimmed[new_cols]

df_trimmed
# Out:
#       brandid  clientid                    slug       rawsize  modelrowcount  \
# 0           1      1594             godaddy-usa  1.570000e+11          13440
# 1           1      1558  barb-save-the-children  1.093499e+09            233
# 2           1      1557        barb-sightsavers  2.868741e+08             28
# 3           1      1557        barb-sightsavers  2.868741e+08             64
# 4           1      1558  barb-save-the-children  1.093499e+09            259
# 5           1      1558  barb-save-the-children  1.093499e+09            284
# 6           1      1557        barb-sightsavers  2.868741e+08             61
# 7           2       952         ihg-holiday-inn  6.122316e+10           4060
# 8           1      1558  barb-save-the-children  1.093499e+09            276
# 9           1      1558  barb-save-the-children  1.093499e+09            248
# 10          2       952         ihg-holiday-inn  6.122316e+10           4222
# ...

# %% [markdown]
# OK ow I want to remove all the datasets that have are being running on a clone

# %%
mask = df_trimmed['cluster_info'].str.contains('clone', na=False)

# this creates a boolean mask for the dataframe, all values containing 'clone' return True.
# The na values that a none value are filled with false.

rem_clones = df_trimmed[mask == False]

#  I actually want the values that are false .e they do not contain clones
# now remove all NaN values

mask = rem_clones['slug'].str.contains('NaN', na=False)
rem_NaN = rem_clones[mask == False]

rem_NaN
# Out:
#       brandid  clientid                    slug       rawsize  modelrowcount  \
# 0           1      1594             godaddy-usa  1.570000e+11          13440
# 1           1      1558  barb-save-the-children  1.093499e+09            233
# 2           1      1557        barb-sightsavers  2.868741e+08             28
# 3           1      1557        barb-sightsavers  2.868741e+08             64
# 4           1      1558  barb-save-the-children  1.093499e+09            259
# 5           1      1558  barb-save-the-children  1.093499e+09            284
# 6           1      1557        barb-sightsavers  2.868741e+08             61
# 7           2       952         ihg-holiday-inn  6.122316e+10           4060
# 8           1      1558  barb-save-the-children  1.093499e+09            276
# 9           1      1558  barb-save-the-children  1.093499e+09            248
# 10          2       952         ihg-holiday-inn  6.122316e+10           4222
# ...

# %% [markdown]
# Next I want to relable the value of modelrowcount

# %%
rename = rem_NaN.rename(columns={'modelrowcount': 'total_number_of_spots_upld'})
rename
rename.to_csv('~/DataAnalysis/trimmed_large_general_jobqueue_dataset.csv')

# %%
# need to trim out all the NaN values
# this is done using the slug column

# mask = pd.isnull(rename['slug'])
# rem_nan = rename[mask == False]

# rem_nan

# this didn't work!! actually yes it did!!

rename.dropna(subset=['slug'], inplace=True)
rename.info()

#This also works
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1814 entries, 0 to 2060
# Data columns (total 19 columns):
# brandid                       1814 non-null int64
# clientid                      1814 non-null int64
# slug                          1814 non-null object
# rawsize                       1814 non-null float64
# total_number_of_spots_upld    1814 non-null int64
# spot_duration                 1814 non-null float64
# diffuse                       1814 non-null object
# micro                         1814 non-null object
# max_lag                       1814 non-null float64
# lag_actions                   1814 non-null float64
# jobpriority                   1814 non-null float64
# workticket_duration           1814 non-null float64
# last_job                      1814 non-null object
# last_job_time                 1814 non-null float64
# origin                        1814 non-null object
# lag                           1814 non-null object
# ...

# %% [markdown]
# make my first plot!!! YESSSSS!!!!!!

# %%
rename.plot.scatter(x='rawsize', y='workticket_duration', logx=True, title='workticket_duration vs db size(log)')

# get this to display with a logarythmic scales using logx=True

# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1= plt.gca()

# create the data type to be entered in the graph
ax1.scatter(rename['rawsize'], rename['workticket_duration'], marker="o", color='b', label='workticket durration' )

# chart axes, title and legend
plt.title("workticket duration vs database size")
plt.ylabel("workticket duration")
plt.xlabel("database rawsize")
ax1.set_xscale('log')


# figure boundaries

plt.show()

# %%
# create plot where the outliers have been omitted
rename = rename[rename.workticket_duration < 750000]

rename

rename.plot.scatter(x='rawsize', y='workticket_duration', logx=True, title='workticket_duration vs db size(log)')

# get this to display with a logarythmic scales using logx=True

# create a figure
fig1 = plt.figure(figsize=(10,8))
ax1 = plt.gca()
# can add a second plot to the graph using an additional thing
ax2 = plt.gca()

# create the data type to be entered in the graph
ax1.scatter(rename['rawsize'], rename['workticket_duration'], marker="o", color='b', label='workticket durration' )
ax2.plot([1048576,2097152,4194304,8388608,16777216,33554432,67108864,134217728,
          268435456,536870912,1073741824,2147483648,4294967296,8589934592,17179869184,
          34359738368,68719476736,137438953472,274877906944,549755813888],
         [10002.09715,10004.1943,10008.38861,10016.77722,10033.55443,10067.10886,
          10134.21773,10268.43546,10536.87091,11073.74182,12147.48365,14294.9673,
          18589.93459,27179.86918,44359.73837,78719.47674,147438.9535,284877.9069,
          559755.8139,1109511.628], linestyle='-', linewidth=2)

# chart axes, title and legend
plt.title("workticket duration vs database size")
plt.ylabel("workticket duration")
plt.xlabel("database rawsize")
ax1.set_xscale('log')

# can edit the axes of each system using this 
ax1.axis([10000000, 2000000000000, -10000,500000])


# figure boundaries

# can I add an equation to this graph?
# no, matplot plots datapoints not equations
# plot([1048576,33554432,1073741824,34359738368,5.49756E+11],[10002.09715, 10067.10886,12147.48365,78719.47674,1109511.628], linestyle='-', linewidth=2)



plt.show()

# %%
# I want to make a histogram to determine whether the distribution of values in a workticket is gaussian or not

hist_data = rename[rename.rawsize == 5904161304]
print (hist_data.head())

trimmed_hist_data = pd.Series(hist_data['workticket_duration'])
print (trimmed_hist_data.head())
# print trimmed_hist_data
plt.hist(trimmed_hist_data)
plt.show()

# OK it appears that it isn't. I now want to look at the data below 2000 ot see if at least some of the data is gaussian

# filter hist_date for data that has a workticket duration less than 2000
filtered_hist_data = hist_data[hist_data.workticket_duration < 2000]
filted_hist_series = pd.Series(filtered_hist_data['workticket_duration'])
plt.hist(filted_hist_series, bins=50)
plt.show()
# Out:
#      brandid  clientid      slug       rawsize  total_number_of_spots_upld  \
# 47         1       994  fracture  5.904161e+09                          67
# 48         1       994  fracture  5.904161e+09                          19
# 182        1       994  fracture  5.904161e+09                          24
# 183        1       994  fracture  5.904161e+09                          67
# 221        1       994  fracture  5.904161e+09                          47
#
#      spot_duration diffuse micro  max_lag  lag_actions  jobpriority  \
# 47        691200.0    True  True     14.0          1.0      1008.01
# 48        432000.0    True  True     14.0          1.0      1008.01
# 182       604800.0    True  True     14.0          1.0      1008.01
# 183       691200.0    True  True     14.0          1.0      1008.01
# 221       604800.0    True  True     14.0          1.0      1008.01
#
#      workticket_duration       last_job  last_job_time origin   lag  \
# ...

# %%
# I want to work out the what is the 95 % percentile value for all values in this dataset

# take only the relevant columns of databasesize and workticket duration
rename.head()

rawsize_percentile_analysis = rename[['workticket_duration', 'rawsize']]

# now group by db size

grouped = rawsize_percentile_analysis.groupby('rawsize')
# this description will now return the 0.95 percentile in addition to the other descriptive statistics




grouped_description = grouped.describe(percentiles=[0.25, 0.5, 0.75, 0.995])
grouped_description.iloc[:,[[0][0],[7][0]]]
reset_index = grouped_description.reset_index()
print (reset_index.head())

# this seems to be nested in some way not sure how to sort


# I will now try and plot all of these as I did before, might still be worth removing all the ridiculous outliers 
# present in the above dataset.

#  remove all values with only 1 entry

 
# only_mulitples = grouped_description[grouped_description.workticket_duration.count > 3]
# only_mulitples

reset_index.to_csv('~/DataAnalysis/csv_files/horrible_hack.csv')
# Out:
#       rawsize workticket_duration                                     \
#                             count        mean          std       min
# 0  11926040.0                 4.0   555.66275   125.456994   383.955
# 1  11934232.0                 1.0  3263.18100          NaN  3263.181
# 2  11983384.0                 6.0  1035.49900  1393.449775   271.570
# 3  13244952.0                 1.0  5820.88000          NaN  5820.880
# 4  13777432.0                 1.0  3500.00400          NaN  3500.004
#
#
#          25%       50%         75%        99.5%       max
# 0   512.3700   579.399   622.69175   678.753875   679.898
# 1  3263.1810  3263.181  3263.18100  3263.181000  3263.181
# 2   302.0185   385.517   910.52475  3742.488850  3810.677
# 3  5820.8800  5820.880  5820.88000  5820.880000  5820.880
# 4  3500.0040  3500.004  3500.00400  3500.004000  3500.004

# %%
reset = pd.read_csv('~/DataAnalysis/csv_files/horrible_hack.csv')

# where count = 1 remove 
trimmed = reset[['rawsize','count','995%']]

trimmed.head()
# trimmed_rem_count_1 = trimmed[trimmed.count == 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-032dbfc5a1a5> in <module>()
#       2
#       3 # where count = 1 remove
# ----> 4 trimmed = reset[['rawsize','count','995%']]
#       5
#       6 trimmed.head()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...
